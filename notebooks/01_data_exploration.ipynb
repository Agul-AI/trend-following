# %% [markdown]
# # Data Exploration
#
# Run `python scripts/download_data.py --config configs/default.yaml` first, then load `data/processed/adjusted_close.parquet` and inspect coverage, missing values, and returns.
