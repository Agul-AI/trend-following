# %% [markdown]
# # Strategy Backtest
#
# Use the scripts for reproducible runs. This notebook is a lightweight place to inspect saved metrics, weights, and figures after running `scripts/run_backtest.py`.
